# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshbabuvaddineni/Deep_Learning/blob/main/Pretrained_models_VGG%2CResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  vgg16
#  vgg19
#  resnet
#  inception(google net)
#  mobile net
#  nasnet
#  efficient net

# %% [markdown]
# # VGG Model

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions

# %%
import numpy as np

# %%
model=VGG16(weights='imagenet')

# %%
img_path="/content/drive/MyDrive/Deep Learning Ineuron/Convolution Neural Network/dataset/single_prediction/cat_or_dog_1.jpg"

# %%
img=image.load_img(img_path,target_size=(224,224))

# %%
img #this image is not in the form of array
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
img=image.img_to_array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img=np.expand_dims(img,axis=0)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
prediction=model.predict(img)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
decode_predictions(prediction)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.62396455),
#   ('n02109047', 'Great_Dane', 0.12550172),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.11461431),
#   ('n02092339', 'Weimaraner', 0.06848529),
#   ('n02104029', 'kuvasz', 0.018542532)]]

# %% [markdown]
# # Resnet

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

# %%
model2=ResNet50(weights='imagenet')

# %%
img=preprocess_input(img)

# %%
prediction=model2.predict(img)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
decode_predictions(prediction)
# Out:
# [[('n02099712', 'Labrador_retriever', 0.71059936),
#   ('n02099601', 'golden_retriever', 0.26151237),
#   ('n02087394', 'Rhodesian_ridgeback', 0.013604638),
#   ('n02099849', 'Chesapeake_Bay_retriever', 0.00300753),
#   ('n02088466', 'bloodhound', 0.0010761666)]]
